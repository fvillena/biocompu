# %%
import sklearn.datasets
import matplotlib.pyplot as plt
import pandas as pd

# %%
blobs_x, blobs_y = sklearn.datasets.make_blobs(n_samples=1000, centers=5)
plt.scatter(blobs_x[:,0], blobs_x[:,1])

# %%
pd.DataFrame(blobs_x,columns=["x","y"]).to_csv("data/blobs.csv",index=False)

# %%
microarray = pd.read_csv("data/gene_expressions.tsv", sep="\t", index_col="gene", nrows=60)

# %%
microarray
# Out:
#              786-0      A498      A549      ACHN    BT-549    CAKI-1  \
# gene
# A1BG     -1.025477 -0.925477  0.274523 -0.875477  2.484523  1.244523
# A2M      -1.409323 -1.409323 -1.409323 -1.409323 -1.409323 -1.399323
# A2ML1    -1.696062 -1.686062 -1.686062 -1.686062 -1.696062 -1.696062
# A4GALT    1.978677  1.588677  0.908677  0.348677  1.098677  1.488677
# AAAS      0.878385  0.178385  1.658385 -0.291615 -0.011615  0.568385
# AACS     -0.354923 -0.184923 -0.074923 -0.014923 -2.114923 -0.504923
# AADAC    -0.809323 -0.389323  0.880677 -0.809323 -0.809323 -0.809323
# AAED1     1.419631  1.779631  0.809631  1.179631  1.379631  0.119631
# AAGAB     0.369015  0.249015  0.649015 -0.500985 -0.630985 -0.380985
# AAMP     -0.128523 -0.198523  0.381477 -1.038523 -1.168523 -0.048523
# AAR2      0.043877 -0.386123  0.243877 -1.556123 -0.376123 -0.786123
# AARS      0.603108 -0.136892  1.373108  0.373108  0.893108  0.553108
# ...
